# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import userdata
token = userdata.get('chave_git') #chave_git

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git init funk_ai
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/funk_ai/.git/

# %%
# %cd funk_ai/
# Out:
# [Errno 2] No such file or directory: 'funk_ai/'
# /content/drive/MyDrive/funk_ai

# %%
# %ls -a
# Out:
# .git/

# %%
# !git status
# Out:
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git add .

# %%
! git status
# Out:
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git config --global user.email "jesusyepez26@gmail.com"
# !git config --global user.name "yepez26"

# %%
# !git commit -m "initial commit"
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
username = 'yepez26'
repository = 'funk_ai'
git_token = token

# %%
# !git remote add <remote-name> https://{git_token}@github.com/{username}/{repository}.git
# Out:
# /bin/bash: line 1: remote-name: No such file or directory

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# !git remote -v
# Out:
# error: remote origin already exists.
# origin	https://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@github.com/yepez26/funk_ai.git (fetch)
# origin	https://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@github.com/yepez26/funk_ai.git (push)

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any
# error: failed to push some refs to 'https://github.com/yepez26/funk_ai.git'

# %%
# !git branch

# %%
# !git branch -M main

# %%
# !git checkout master
# Out:
# error: pathspec 'master' did not match any file(s) known to git

# %%
# !git status
# Out:
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# Add changes, commit, and push
# !git add .
# !git commit -m "Your commit message here"
# !git push -u origin master
# Out:
# On branch master
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)
# error: src refspec master does not match any
# error: failed to push some refs to 'https://github.com/{username}/{repository}.git'

# %%
# Add remote origin
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git

# Verify remote
# !git remote -v

# Add changes, commit, and push
# !git add .
# !git commit -m "Your commit message here"
# !git push -u origin master
# Out:
# error: remote origin already exists.
# origin	https://{git_token}@github.com/{username}/{repository}.git (fetch)
# origin	https://{git_token}@github.com/{username}/{repository}.git (push)
# On branch master
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)
# error: src refspec master does not match any
# error: failed to push some refs to 'https://github.com/{username}/{repository}.git'
